# %% [markdown]
# # Visualization of Covid 19 Data of Italy

# %%
import numpy as np
import pandas as pd
import seaborn as sn #for visualization
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"F:\datasets\covid19\italy\covid19_italy_region.csv") #loading the dataset

# %%
data #entire dataset
# Out:
#        SNo                 Date Country  RegionCode     RegionName   Latitude  \
# 0        0  2020-02-24T18:00:00     ITA          13        Abruzzo  42.351222
# 1        1  2020-02-24T18:00:00     ITA          17     Basilicata  40.639471
# 2        2  2020-02-24T18:00:00     ITA          21   P.A. Bolzano  46.499335
# 3        3  2020-02-24T18:00:00     ITA          18       Calabria  38.905976
# 4        4  2020-02-24T18:00:00     ITA          15       Campania  40.839566
# ...    ...                  ...     ...         ...            ...        ...
# 2074  2074  2020-06-01T17:00:00     ITA           9        Toscana  43.769231
# 2075  2075  2020-06-01T17:00:00     ITA          22    P.A. Trento  46.068935
# 2076  2076  2020-06-01T17:00:00     ITA          10         Umbria  43.106758
# 2077  2077  2020-06-01T17:00:00     ITA           2  Valle d'Aosta  45.737503
# 2078  2078  2020-06-01T17:00:00     ITA           5         Veneto  45.434905
#
# ...

# %%
#no. of columns
len(data.columns)
# Out:
# 17

# %%
#no. of rows
len(data)
# Out:
# 2079

# %%
data.head() #1st 5 rows
# Out:
#    SNo                 Date Country  RegionCode    RegionName   Latitude  \
# 0    0  2020-02-24T18:00:00     ITA          13       Abruzzo  42.351222
# 1    1  2020-02-24T18:00:00     ITA          17    Basilicata  40.639471
# 2    2  2020-02-24T18:00:00     ITA          21  P.A. Bolzano  46.499335
# 3    3  2020-02-24T18:00:00     ITA          18      Calabria  38.905976
# 4    4  2020-02-24T18:00:00     ITA          15      Campania  40.839566
#
#    Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0  13.398438                     0                      0
# 1  15.805148                     0                      0
# 2  11.356624                     0                      0
# 3  16.594402                     0                      0
# 4  14.250850                     0                      0
#
#    TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# 0                          0                0                     0
# ...

# %%
data.columns #the column labels of the dataset
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
data.tail() #last 5 rows
# Out:
#        SNo                 Date Country  RegionCode     RegionName   Latitude  \
# 2074  2074  2020-06-01T17:00:00     ITA           9        Toscana  43.769231
# 2075  2075  2020-06-01T17:00:00     ITA          22    P.A. Trento  46.068935
# 2076  2076  2020-06-01T17:00:00     ITA          10         Umbria  43.106758
# 2077  2077  2020-06-01T17:00:00     ITA           2  Valle d'Aosta  45.737503
# 2078  2078  2020-06-01T17:00:00     ITA           5         Veneto  45.434905
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 2074  11.255889                    85                     25
# 2075  11.121231                    14                      3
# 2076  12.388247                    15                      2
# 2077   7.320149                    11                      0
# 2078  12.338452                   110                      6
#
#       TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# ...

# %%
data.describe()
# Out:
#                SNo   RegionCode     Latitude    Longitude  \
# count  2079.000000  2079.000000  2079.000000  2079.000000
# mean   1039.000000    11.857143    43.046293    12.225955
# std     600.299925     6.275308     2.489380     2.659587
# min       0.000000     1.000000    38.115697     7.320149
# 25%     519.500000     7.000000    41.125596    11.121231
# 50%    1039.000000    12.000000    43.616760    12.388247
# 75%    1558.500000    17.000000    45.434905    13.768136
# max    2078.000000    22.000000    46.499335    16.867367
#
#        HospitalizedPatients  IntensiveCarePatients  TotalHospitalizedPatients  \
# count           2079.000000            2079.000000                2079.000000
# mean             734.296296              86.062049                 820.358345
# std             1703.530432             180.023765                1877.264377
# min                0.000000               0.000000                   0.000000
# ...

# %%
data.isnull().sum()
# Out:
# SNo                             0
# Date                            0
# Country                         0
# RegionCode                      0
# RegionName                      0
# Latitude                        0
# Longitude                       0
# HospitalizedPatients            0
# IntensiveCarePatients           0
# TotalHospitalizedPatients       0
# HomeConfinement                 0
# CurrentPositiveCases            0
# NewPositiveCases                0
# Recovered                       0
# Deaths                          0
# TotalPositiveCases              0
# TestsPerformed               1155
# dtype: int64

# %%
#relationship betwwen total positive cases & recovered
sn.relplot(x="TotalPositiveCases",y="Recovered",data=data)
#CONCLUSION: people are recovering from the disease as the no. of cases are increasing

# %%
#relationship betwwen total positive cases & deaths
sn.relplot(x="TotalPositiveCases",y="Deaths",data=data)
#CONCLUSION: no. of deaths have increased as the no. of cases have increased

# %%
#relationship betwwen total positive cases & total hospitalized patients
sn.relplot(x="TotalPositiveCases",y="TotalHospitalizedPatients", hue="Recovered",data=data)
#CONCLUSION: upto a certain time (around 40,000 cases)the no. of hospitalisations increased as the no. of cases increased
             #However, after that we see that the no. of hospitalisations decreased as the no. of cases increased
             #Also, the recovery rate increased as the no. of cases increased

# %%
#pairwise relationship of each parameter
sn.pairplot(data)
# Out:
# C:\Users\Souvik\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Souvik\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
#line plot
sn.relplot(x="HomeConfinement",y="TotalPositiveCases",kind="line",data=data)
#CONCLUSION: cases still increased as the home confinement increased

# %%
#line plot
sn.relplot(x="HomeConfinement",y="Recovered",kind="line",data=data)
#CONCLUSION: people are recovering more from the disease as the home confinement is increasing

# %%
#death rate region-wise
sn.catplot(x="Deaths",y="RegionName",data=data)
#CONLCUSION: Lombardia has the maximum deaths

# %%
#recovery rate region-wise
sn.catplot(x="Recovered",y="RegionName",data=data)
#CONCLUSION: Lombardia has the maxmimum recoveries
